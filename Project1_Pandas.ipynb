# %% [markdown]
# <a href="https://colab.research.google.com/github/joshikarthikeyan4-pixel/Project1.pandas/blob/main/Project1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os
import zipfile

# Define the path to the uploaded zip file and the extraction directory
zip_file_path = '/content/archive (1).zip'
extract_path = '/content/extracted_data'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List the files in the extracted directory to confirm the extraction
extracted_files = os.listdir(extract_path)
print("Extracted files:", extracted_files)
# Out:
# Extracted files: ['netflix_titles.csv']

# %%
csv_file_path = os.path.join(extract_path, 'netflix_titles.csv')
df = pd.read_csv(csv_file_path)
display(df.head())
df
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
csv_file_path = os.path.join(extract_path, 'netflix_titles.csv')
df = pd.read_csv(csv_file_path)
display(df.head())
df
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print(df.head(3))
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
print(df.tail(4))
# Out:
#      show_id     type        title         director  \
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating   duration  \
# 8803      July 1, 2019          2018  TV-Y7  2 Seasons
# 8804  November 1, 2019          2009      R     88 min
# 8805  January 11, 2020          2006     PG     88 min
# 8806     March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.dropna(how="any")
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df_dup=df.drop_duplicates(keep='last')
df_dup
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['type'].value_counts() #it is telling the various genres
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States                                                      2818
# India                                                               972
# United Kingdom                                                      419
# Japan                                                               245
# South Korea                                                         199
#                                                                    ...
# Mexico, United States, Spain, Colombia                                1
# Canada, Norway                                                        1
# Finland, Germany, Belgium                                             1
# Argentina, United States, Mexico                                      1
# United Kingdom, United States, Germany, Denmark, Belgium, Japan       1
# Name: count, Length: 748, dtype: int64

# %%
df.director.value_counts()
# Out:
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Suhas Kadav                16
# Marcus Raboy               16
# Jay Karas                  14
#                            ..
# James Brown                 1
# Ivona Juka                  1
# Mu Chu                      1
# Chandra Prakash Dwivedi     1
# Majid Al Ansari             1
# Name: count, Length: 4528, dtype: int64

# %% [markdown]
#   Q1-what is the total number of movies and tv shows?

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# Q2-Which country has the most netflix titles?

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %% [markdown]
# Q3- Which year had the highest number of new releases?

# %%
df['release_year'].value_counts().sort_index(ascending=True).tail(10)
# Out:
# release_year
# 2012     237
# 2013     288
# 2014     352
# 2015     560
# 2016     902
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, dtype: int64

# %% [markdown]
# Q4- Which country has the most TV Shows vs Movies?

# %%
df.groupby(['country', 'type']).size().unstack().fillna(0).sort_values(by='Movie', ascending=False).head(10)
# Out:
# type             Movie  TV Show
# country
# United States   2058.0    760.0
# India            893.0     79.0
# United Kingdom   206.0    213.0
# Canada           122.0     59.0
# Spain             97.0     48.0
# Egypt             92.0     14.0
# Nigeria           86.0      9.0
# Indonesia         77.0      2.0
# Turkey            76.0     29.0
# Japan             76.0    169.0

# %% [markdown]
# # conclusions:-
# 1)-Movies are released more than tv shows in netflix.
# <br>
# 2)-The United States has the most number of movies and tv shows released.
# <br>
# 3)-The content of Netflix grew massively after 2015.
# <br>
# 4)-Most of the netflix content is movies.
